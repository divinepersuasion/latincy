# %% [markdown]
# Références
#
# ```bibtex
# @misc{burns2023latincysynthetictrainedpipelines,
#       title={LatinCy: Synthetic Trained Pipelines for Latin NLP},
#       author={Patrick J. Burns},
#       year={2023},
#       eprint={2305.04365},
#       archivePrefix={arXiv},
#       primaryClass={cs.CL},
#       url={https://arxiv.org/abs/2305.04365},
# }
# ```
# tutorial : https://diyclassics.github.io/latincy-book/

# %%
# !python --version
# !which python
# Out:
# Python 3.12.3
# /home/floriane/Documents/visual_code/.latinCy12/bin/python

# %% [markdown]
# Lemmatization with spacy for NER

# %%
# Imports & setup

import spacy
from pprint import pprint
nlp = spacy.load('la_core_web_sm')
files = ['De_somniis/De_somniis.txt']

for filename in files:
    print(f"\n{'-'*50}")
    print(f"Processing: {filename}")
   
    
    with open(filename, 'r', encoding='utf-8') as f:
        text = f.read()

doc = nlp(text)
print(doc)
# Out:
# --------------------------------------------------
# Processing: De_somniis/De_somniis.txt
# Ad Hugonem Eterianum doctorem suum et utraque origine fratrem Leo Tuscus imperatoriarum epistolarum interpres de somniis et oraculis. Quamquam optime preceptor invictum imperatorem Manuel per fines sequar Bitinie Licaonieque fugantem Persas flexipedum hederarum complectentes vestigia tamen memorandi non sum oblitus somnii a te visi qui dictum inexpugnabilem virum eneo in equo supra columnam quam Traces dicunt augustiana Bisantii sito nobiliter sedere conspicabaris Eodem autem in loco doctissimis quibusdam astantibus latinis romana oratione cum in quodam legeret libello interpellanti tibi soli favorem prestitisse visus est latuit tunc utrumque nostrum ea quid portenderet visio at vero eiusmodi oraculum editus per te de filii hominis minoritate ad Patrem Deum libellus tempore post revelavit sub tegumentis profecto eneus ille sonipes anima carens altissime sonantissimeque questionis erat que inter Grecos versabatur ventilatio verbum scilicet Dei secundum quod incarnatum patri equale protestans rationis veritatisque radicitus expers ut quadrupes nominatus solvit autem illam controversiam clamitante dicto libello augustalis clementie decretum pauco scandali fomento contra voluntatem illius relicto. Ex eo igitur tempore pectus sollicitudine percussi sub corde ignitos versavi carbones cogitando uti lene esset annon si onirocriti Grecorum philosophis ariolanti loqui latine persuaderem enucleatim atque inoffensam perspicuitatem figmenti somnialis tuo favore nostrorum Tuscorum desiderio breviter reserarem quos quidem fluctu percupio aspergi undiosiore ut irrigentur affatim efficianturque fecundiores nam Seres ut fertur arbores suas undis aspergunt quando uberiorem lanuginem que sericum admittere nituntur ceterum haut facile est in huiusmodi versari pelago cuius latitudo ad aures usque dehiscit non sponte remigem asciscens invalidum non solum enim subtilibus expositum investigationibus et illos repellunt qui debilitate pedum serpunt ut antipodes et eos qui non movent linguas ut pleraque aquatilium sed nequemonoxilo se navigari limine patitur quamobrem loquelam imperatoriorum interpretationibus apicum obsequentem per excubias interdum huic translationi non irrita spe addixi totum opus sapientie tue dicaturus iudicio mei quidem auctoris tui vero probatoris equilibre pensans incertum nam tuum examen discernere non sum ambiguus quicquid arida exsanguisque poscit ratiocinatio sed enim desiderantissimus nepos Fabricius grecarum sciolus et ipse litterarum somnialium figmentorum odoratus rosaria scribendi assiduitate me a confluentibus elevat prestatque non mediocre adiumentum atque idcirco neque nomen sine subjecto neque sine viribus erit editio Sidoneis Tirenisque sagittis parum penetrabilis apparitura ut arbitror ergo quisquis nodosorum somniorum fatigatur involucris si per aliquod hic scriptorum absolvi postulet caveat pretemptare plus nosse quam sat est ne titulos depravetApollinee urbis ambiguum rimis herbidisque sentibus ego autem tui solius utrarumque linguarum peritissimo examinivolumen hoc subpono ut in eo que arescunt ac caligant per te illustrata orbi demum succincta professione vulgentur.

# %%
print(nlp.pipe_names)
# Out:
# ['senter', 'normer', 'tok2vec', 'tagger', 'morphologizer', 'trainable_lemmatizer', 'parser', 'lookup_lemmatizer', 'ner', 'remorpher']

# %%
import tabulate

data = []

tokens = [item for item in doc]

for token in tokens:
    data.append([token.text, token.lemma_])    

print(tabulate.tabulate(data, headers=['Text', 'Lemma']))
# Out:
# Text                Lemma
# ------------------  ------------------
# Ad                  ad
# Hugonem             Hugon
# Eterianum           Eterianus
# doctorem            doctor
# suum                suus
# et                  et
# utraque             uterque
# origine             origo
# fratrem             frater
# Leo                 Leo
# Tuscus              tuscus
# imperatoriarum      imperatorius
# epistolarum         epistola
# interpres           interpres
# de                  de
# somniis             somnium
# et                  et
# oraculis            oraculum
# .                   .
# Quamquam            quamquam
# optime              optimus
# preceptor           preceptor
# invictum            inuictus
# imperatorem         imperator
# Manuel              Manuel
# per                 per
# fines               finis
# sequar              sequor
# Bitinie             Bitinie
# Licaonie            Licaonie
# que                 que
# fugantem            fugo
# Persas              Persa
# flexipedum          flexipedus
# hederarum           hedera
# complectentes       complector
# vestigia            uestigium
# tamen               tamen
# memorandi           memoro
# non                 non
# sum                 sum
# oblitus             obliuiscor
# somnii              somnium
# a                   ab
# te                  tu
# visi                uiso
# qui                 qui
# dictum              dictum
# inexpugnabilem      inexpugnabilis
# virum               uir
# eneo                eneo
# in                  in
# equo                equus
# supra               supra
# columnam            columna
# quam                qui
# Traces              Traces
# dicunt              dico
# augustiana          augustianus
# Bisantii            Bisantii
# sito                sino
# nobiliter           nobilito
# sedere              sedeo
# conspicabaris       conspicor
# Eodem               idem
# autem               autem
# in                  in
# loco                locus
# doctissimis         doctissimus
# quibusdam           quidam
# astantibus          asto
# latinis             latinus
# romana              romanus
# oratione            oratio
# cum                 cum
# in                  in
# quodam              quidam
# legeret             lego
# libello             libellus
# interpellanti       interpello
# tibi                tu
# soli                solum
# favorem             fauor
# prestitisse         prestito
# visus               uisus
# est                 sum
# latuit              lateo
# tunc                tunc
# utrumque            uterque
# nostrum             noster
# ea                  is
# quid                quis
# portenderet         portendo
# visio               uisio
# at                  at
# vero                uero
# eiusmodi            eiusmodi
# oraculum            oraculum
# editus              edo
# per                 per
# te                  tu
# de                  de
# filii               filius
# hominis             homo
# minoritate          minoritas
# ad                  ad
# Patrem              pater
# Deum                Deus
# libellus            libellus
# tempore             tempus
# post                post
# revelavit           reuelo
# sub                 sub
# tegumentis          tegumentum
# profecto            prŏfectus
# eneus               eneus
# ille                ille
# sonipes             sonipes
# anima               anima
# carens              careo
# altissime           alte
# sonantissime        sonantus
# que                 que
# questionis          quaestio
# erat                sum
# que                 que
# inter               inter
# Grecos              Graecus
# versabatur          uersor
# ventilatio          uentilatio
# verbum              uerbum
# scilicet            scilicet
# Dei                 Deus
# secundum            secundum
# quod                quod
# incarnatum          incarno
# patri               pater
# equale              equalis
# protestans          protestor
# rationis            ratio
# veritatis           ueritas
# que                 que
# radicitus           radicitus
# expers              expers
# ut                  ut
# quadrupes           quadrupes
# nominatus           nomino
# solvit              soluo
# autem               autem
# illam               ille
# controversiam       controuersia
# clamitante          clamito
# dicto               dictum
# libello             libellus
# augustalis          augustalis
# clementie           clementia
# decretum            decerno
# pauco               paucus
# scandali            scandalum
# fomento             fomentum
# contra              contra
# voluntatem          uoluntas
# illius              ille
# relicto             relinquo
# .                   .
# Ex                  ex
# eo                  is
# igitur              igitur
# tempore             tempus
# pectus              pectus
# sollicitudine       sollicitudo
# percussi            percutio
# sub                 sub
# corde               cor
# ignitos             ignio
# versavi             uerso
# carbones            carbo
# cogitando           cogitandus
# uti                 ut
# lene                lenis
# esset               sum
# annon               annon
# si                  si
# onirocriti          onirocro
# Grecorum            Greci
# philosophis         philosophus
# ariolanti           ariolor
# loqui               loquor
# latine              latine
# persuaderem         persuadeo
# enucleatim          enucleatim
# atque               atque
# inoffensam          inoffensus
# perspicuitatem      perspicuitas
# figmenti            figmentum
# somnialis           somnialis
# tuo                 tuus
# favore              fauor
# nostrorum           noster
# Tuscorum            Tuscus
# desiderio           desiderium
# breviter            breuiter
# reserarem           resero
# quos                qui
# quidem              quidem
# fluctu              fluctus
# percupio            percupius
# aspergi             aspergo
# undiosiore          undiosior
# ut                  ut
# irrigentur          irrigo
# affatim             affatim
# efficiantur         efficio
# que                 que
# fecundiores         fecundus
# nam                 nam
# Seres               Seres
# ut                  ut
# fertur              fero
# arbores             arbor
# suas                suus
# undis               unda
# aspergunt           aspergo
# quando              quando
# uberiorem           uberior
# lanuginem           lanugi
# que                 que
# sericum             sericum
# admittere           admitto
# nituntur            nitor
# ceterum             ceterum
# haut                haud
# facile              facilis
# est                 sum
# in                  in
# huiusmodi           huiusmodi
# versari             uersor
# pelago              pelagus
# cuius               qui
# latitudo            latitudo
# ad                  ad
# aures               auris
# usque               usque
# dehiscit            dehisco
# non                 non
# sponte              spons
# remigem             remex
# asciscens           ascisco
# invalidum           invalidus
# non                 non
# solum               solum
# enim                enim
# subtilibus          subtilis
# expositum           expono
# investigationibus   inuestigatio
# et                  et
# illos               ille
# repellunt           repello
# qui                 qui
# debilitate          debilito
# pedum               pes
# serpunt             serpo
# ut                  ut
# antipodes           antipodes
# et                  et
# eos                 is
# qui                 qui
# non                 non
# movent              moueo
# linguas             lingua
# ut                  ut
# pleraque            plerusque
# aquatilium          aquatilium
# sed                 sed
# nequemonoxilo       nequemonoxilum
# se                  sui
# navigari            nauigo
# limine              limen
# patitur             patior
# quamobrem           quamobrem
# loquelam            loquela
# imperatoriorum      imperatorius
# interpretationibus  interpretatio
# apicum              apex
# obsequentem         obsequor
# per                 per
# excubias            excubia
# interdum            interdum
# huic                hic
# translationi        translatio
# non                 non
# irrita              irritus
# spe                 spes
# addixi              addico
# totum               totus
# opus                opus
# sapientie           sapientia
# tue                 tuus
# dicaturus           dico
# iudicio             iudicium
# mei                 meus
# quidem              quidem
# auctoris            auctor
# tui                 tu
# vero                uero
# probatoris          probator
# equilibre           equilibre
# pensans             penso
# incertum            incertus
# nam                 nam
# tuum                tuus
# examen              examen
# discernere          discerno
# non                 non
# sum                 sum
# ambiguus            ambiguus
# quicquid            quisquis
# arida               aridus
# exsanguis           exsanguis
# que                 que
# poscit              posco
# ratiocinatio        ratiocinatio
# sed                 sed
# enim                enim
# desiderantissimus   desiderantisso
# nepos               nepos
# Fabricius           Fabricius
# grecarum            grecarus
# sciolus             sciolus
# et                  et
# ipse                ipse
# litterarum          littera
# somnialium          somnialis
# figmentorum         figmentum
# odoratus            odoratus
# rosaria             rosaria
# scribendi           scribo
# assiduitate         assiduitas
# me                  ego
# a                   ab
# confluentibus       confluens
# elevat              eleuo
# prestat             presto
# que                 que
# non                 non
# mediocre            mediocris
# adiumentum          adiumentum
# atque               atque
# idcirco             idcirco
# neque               neque
# nomen               nomen
# sine                sine
# subjecto            subiectus
# neque               neque
# sine                sine
# viribus             uis
# erit                sum
# editio              editio
# Sidoneis            sidoneus
# Tirenis             Tirenus
# que                 que
# sagittis            sagitta
# parum               parum
# penetrabilis        penetrabilis
# apparitura          appareo
# ut                  ut
# arbitror            arbitror
# ergo                ergo
# quisquis            quisquis
# nodosorum           nodosus
# somniorum           somnium
# fatigatur           fatigo
# involucris          inuolucrum
# si                  si
# per                 per
# aliquod             aliqui
# hic                 hic
# scriptorum          scriptor
# absolvi             absoluo
# postulet            postulo
# caveat              caueo
# pretemptare         pretempto
# plus                plus
# nosse               nosco
# quam                quam
# sat                 satis
# est                 sum
# ne                  ne
# titulos             titulus
# depravetApollinee   depravetApollineeo
# urbis               urbs
# ambiguum            ambiguus
# rimis               rima
# herbidis            herbidus
# que                 que
# sentibus            sentis
# ego                 ego
# autem               autem
# tui                 tu
# solius              solus
# utrarumque          uterque
# linguarum           lingua
# peritissimo         peritissimus
# examinivolumen      examinivolumen
# hoc                 hic
# subpono             subpono
# ut                  ut
# in                  in
# eo                  is
# que                 que
# arescunt            aresco
# ac                  ac
# caligant            caligo
# per                 per
# te                  tu
# illustrata          illustro
# orbi                orbis
# demum               demos
# succincta           succingo
# professione         professio
# vulgentur           uulgo
# .                   .

# %%
print(f'Token: {tokens[3].text}')
print(f'Lemma: {tokens[3].lemma_}')
print(f'Lowercase lemma: {tokens[3].lemma_.lower()}')
print(f'Token: {tokens[3].text}')
print(f'Human-readable lemma: {tokens[3].lemma_}')
print(f'spaCy lemma key: {tokens[3].lemma}')
# Out:
# Token: doctorem
# Lemma: doctor
# Lowercase lemma: doctor
# Token: doctorem
# Human-readable lemma: doctor
# spaCy lemma key: 18058202148154971361

# %%
import copy

P1 = copy.deepcopy(nlp)
P1.disable_pipes((['tagger', 'morphologizer', 'lookup_lemmatizer']))
print(f'First pipeline components: {P1.pipe_names}')

P2 = copy.deepcopy(nlp)
P2.disable_pipes((['tagger', 'morphologizer', 'trainable_lemmatizer']))
print(f'Second pipeline components: {P2.pipe_names}')
# Out:
# First pipeline components: ['senter', 'normer', 'tok2vec', 'trainable_lemmatizer', 'parser', 'ner', 'remorpher']
# Second pipeline components: ['senter', 'normer', 'tok2vec', 'parser', 'lookup_lemmatizer', 'ner', 'remorpher']

# %%
P1_annotations = P1(text)
P2_annotations = P2(text)

data = []

for p1_token, p2_token in zip(P1_annotations, P2_annotations):
    data.append([p1_token.text, p1_token.lemma_, p2_token.lemma_])

print(tabulate.tabulate(data, headers=['Text', 'Trainable lemmatizer', 'Lookup lemmatizer']))
# Out:
# Text                Trainable lemmatizer    Lookup lemmatizer
# ------------------  ----------------------  -------------------
# Ad                  ad
# Hugonem             Hugon
# Eterianum           Eterianus
# doctorem            doctor
# suum                suus
# et                  et
# utraque             uterque                 uterque
# origine             origo                   origo
# fratrem             frater                  frater
# Leo                 Leo                     Leo
# Tuscus              tuscus                  tuscus
# imperatoriarum                              imperatorius
# epistolarum                                 epistola
# interpres           interpres               interpres
# de                  de
# somniis             somnium                 somnium
# et                  et
# oraculis            oraculum                oraculum
# .                   .                       .
# Quamquam            quamquam
# optime              bene                    optimus
# preceptor           preceptor
# invictum            invictus                inuictus
# imperatorem         imperator               imperator
# Manuel              Manuel
# per                 per
# fines               finis                   finis
# sequar              sequor
# Bitinie             Bitinie
# Licaonie            Licaonie
# que                 que
# fugantem            fugans                  fugo
# Persas              Persae                  Persa
# flexipedum          flexipedus
# hederarum           hederar                 hedera
# complectentes       complecteor             complector
# vestigia            uestigium               uestigium
# tamen               tamen
# memorandi           memoro
# non                 non
# sum                 sum                     sum
# oblitus             obliuiscor
# somnii              somnium                 somnium
# a                   ab
# te                  tu                      tu
# visi                uiso
# qui                 qui
# dictum              dictum
# inexpugnabilem      inexpugnabilis          inexpugnabilis
# virum               uir                     uir
# eneo                eneo
# in                  in                      in
# equo                equus                   equus
# supra               supra
# columnam            columna                 columna
# quam                qui
# Traces              Traces
# dicunt              dico                    dico
# augustiana          augustianus
# Bisantii            Bisantii
# sito                sino                    sino
# nobiliter           nobiliter               nobilito
# sedere              sedeo
# conspicabaris                               conspicor
# Eodem               idem                    idem
# autem               autem
# in                  in                      in
# loco                locus
# doctissimis         doctissimis             doctissimus
# quibusdam           quidam                  quidam
# astantibus          astans                  asto
# latinis             latinus                 latinus
# romana              romanus                 romanus
# oratione            oratio                  oratio
# cum                 cum                     cum
# in                  in                      in
# quodam              quidam                  quidam
# legeret             lego                    lego
# libello             libellus                libellus
# interpellanti       interpellans            interpello
# tibi                tu
# soli                solum
# favorem             favor                   fauor
# prestitisse         prestito
# visus               uideo                   uisus
# est                 sum
# latuit              lateo                   lateo
# tunc                tunc
# utrumque            uterque
# nostrum             noster
# ea                  is                      is
# quid                quis                    quis
# portenderet         portendo                portendo
# visio               uisio                   uisio
# at                  at
# vero                uero
# eiusmodi            eiusmodi
# oraculum            oraculum                oraculum
# editus              edo
# per                 per
# te                  tu                      tu
# de                  de
# filii               filius
# hominis             homo                    homo
# minoritate          minoritas               minoritas
# ad                  ad
# Patrem              pater
# Deum                deus                    Deus
# libellus            libellus                libellus
# tempore             tempus                  tempus
# post                post
# revelavit           revelo                  reuelo
# sub                 sub
# tegumentis          tegumentus              tegumentum
# profecto            profecto                prŏfectus
# eneus               eneus
# ille                ille                    ille
# sonipes             sonipes                 sonipes
# anima               anima
# carens              careo                   careo
# altissime           alte
# sonantissime        sonantus
# que                 que
# questionis          quaestio
# erat                sum                     sum
# que                 que
# inter               inter
# Grecos              Greci                   Graecus
# versabatur          uersabo                 uersor
# ventilatio          uentilatio              uentilatio
# verbum              uerbum                  uerbum
# scilicet            scilicet
# Dei                 deus                    Deus
# secundum            secundum
# quod                quod
# incarnatum          incarno                 incarno
# patri               pater                   pater
# equale              equalis
# protestans          protesto                protestor
# rationis            ratio                   ratio
# veritatis           ueritas                 ueritas
# que                 que
# radicitus           radicitus
# expers              expers                  expers
# ut                  ut
# quadrupes           quadrupes               quadrupes
# nominatus           nomino                  nomino
# solvit              soluo
# autem               autem
# illam               ille                    ille
# controversiam       controversia            controuersia
# clamitante          clamito                 clamito
# dicto               dictum
# libello             libellus                libellus
# augustalis          augustalis
# clementie           clementia
# decretum            decerno
# pauco               paucus                  paucus
# scandali            scandalis               scandalum
# fomento             fomentum                fomentum
# contra              contra
# voluntatem          uoluntas                uoluntas
# illius              ille                    ille
# relicto             relinquo                relinquo
# .                   .                       .
# Ex                  ex
# eo                  is
# igitur              igitur
# tempore             tempus                  tempus
# pectus              pectus                  pectus
# sollicitudine       sollicitudo             sollicitudo
# percussi            percutio                percutio
# sub                 sub
# corde               cor                     cor
# ignitos                                     ignio
# versavi             verso                   uerso
# carbones            carbo                   carbo
# cogitando           cogito                  cogitandus
# uti                 ut
# lene                lenis                   lenis
# esset               sum
# annon               annon
# si                  si
# onirocriti          onirocro
# Grecorum            Greci
# philosophis         philosophus             philosophus
# ariolanti           ariolans                ariolor
# loqui               loquor                  loquor
# latine              latine                  latine
# persuaderem         persuader               persuadeo
# enucleatim          enucleatim
# atque               atque
# inoffensam          inoffensus
# perspicuitatem      perspicuitas            perspicuitas
# figmenti            figmo                   figmentum
# somnialis           somnialis
# tuo                 tuus                    tuus
# favore              favor                   fauor
# nostrorum           noster                  noster
# Tuscorum            Tusci                   Tuscus
# desiderio           desiderium              desiderium
# breviter            breviter                breuiter
# reserarem           resero                  resero
# quos                qui
# quidem              quidem
# fluctu              fluctus                 fluctus
# percupio            percupius
# aspergi             aspergo                 aspergo
# undiosiore          undiosior
# ut                  ut
# irrigentur                                  irrigo
# affatim             affatim
# efficiantur                                 efficio
# que                 que
# fecundiores         fecundus
# nam                 nam
# Seres               Seres                   Seres
# ut                  ut
# fertur              fero                    fero
# arbores             arbor                   arbor
# suas                suus
# undis               unda                    unda
# aspergunt           aspergo                 aspergo
# quando              quando
# uberiorem           uberior                 uberior
# lanuginem           lanugi
# que                 que
# sericum             sericus                 sericum
# admittere           admitto                 admitto
# nituntur            nitor                   nitor
# ceterum             ceterum
# haut                haud
# facile              facilis
# est                 sum
# in                  in                      in
# huiusmodi           huiusmodi
# versari             uerso                   uersor
# pelago              pelagus                 pelagus
# cuius               qui
# latitudo            latitudo                latitudo
# ad                  ad
# aures               auris
# usque               usque
# dehiscit            dehisco
# non                 non
# sponte              sponte                  spons
# remigem             remix                   remex
# asciscens           ascisco                 ascisco
# invalidum           invalidus
# non                 non
# solum               solum
# enim                enim
# subtilibus          subtilis                subtilis
# expositum           expono
# investigationibus   investigation           inuestigatio
# et                  et
# illos               ille                    ille
# repellunt           repello                 repello
# qui                 qui
# debilitate          debilitas               debilito
# pedum               pes                     pes
# serpunt             serpo                   serpo
# ut                  ut
# antipodes           antipodes
# et                  et
# eos                 is                      is
# qui                 qui
# non                 non
# movent              movo                    moueo
# linguas             lingua                  lingua
# ut                  ut
# pleraque            plerusque
# aquatilium          aquatilium
# sed                 sed
# nequemonoxilo       nequemonoxilum
# se                  sui
# navigari            navigo                  nauigo
# limine              limen                   limen
# patitur             patior                  patior
# quamobrem           quamobrem
# loquelam            loquela                 loquela
# imperatoriorum      imperatorius            imperatorius
# interpretationibus  interpretation          interpretatio
# apicum              apicus                  apex
# obsequentem         obsequens               obsequor
# per                 per
# excubias            excubiae                excubia
# interdum            interdum
# huic                hic                     hic
# translationi        translatio              translatio
# non                 non
# irrita              irritus                 irritus
# spe                 spes                    spes
# addixi              addico                  addico
# totum               totus
# opus                opus                    opus
# sapientie           sapientia
# tue                 tuus                    tuus
# dicaturus           dico                    dico
# iudicio             iudicium                iudicium
# mei                 meus
# quidem              quidem
# auctoris            auctor                  auctor
# tui                 tuus                    tu
# vero                uero
# probatoris          probator                probator
# equilibre           equilibre
# pensans             penso                   penso
# incertum            incertus                incertus
# nam                 nam
# tuum                tuus
# examen              examen                  examen
# discernere          discerno                discerno
# non                 non
# sum                 sum                     sum
# ambiguus            ambiguus                ambiguus
# quicquid            quisquis
# arida               aridus                  aridus
# exsanguis           exsanguis               exsanguis
# que                 que
# poscit              posco                   posco
# ratiocinatio        ratiocinatio            ratiocinatio
# sed                 sed
# enim                enim
# desiderantissimus   desiderantisso
# nepos               nepos                   nepos
# Fabricius           Fabricius               Fabricius
# grecarum            grecarus
# sciolus             sciolus                 sciolus
# et                  et
# ipse                ipse                    ipse
# litterarum          littera                 littera
# somnialium          somnialis
# figmentorum         figmentus               figmentum
# odoratus            odoratus
# rosaria             rosaria
# scribendi           scribo
# assiduitate         assiduito               assiduitas
# me                  ego                     ego
# a                   ab
# confluentibus       confluent               confluens
# elevat              elevao                  eleuo
# prestat             presto
# que                 que
# non                 non
# mediocre            mediocris               mediocris
# adiumentum          adiumentum              adiumentum
# atque               atque
# idcirco             idcirco
# neque               neque
# nomen               nomen
# sine                sine
# subjecto            subjectus               subiectus
# neque               neque
# sine                sine
# viribus             uis                     uis
# erit                sum
# editio              editio                  editio
# Sidoneis            sidoneus
# Tirenis             Tirenus
# que                 que
# sagittis            sagitta                 sagitta
# parum               parum                   parum
# penetrabilis        penetrabilis            penetrabilis
# apparitura          appareo                 appareo
# ut                  ut
# arbitror            arbitror                arbitror
# ergo                ergo
# quisquis            quisquis                quisquis
# nodosorum           nodosus                 nodosus
# somniorum           somnium                 somnium
# fatigatur                                   fatigo
# involucris                                  inuolucrum
# si                  si
# per                 per
# aliquod             aliqui                  aliqui
# hic                 hic                     hic
# scriptorum          scriptor
# absolvi             absoluo                 absoluo
# postulet            postulo                 postulo
# caveat              caveo                   caueo
# pretemptare         pretempto
# plus                multus                  plus
# nosse               nosco
# quam                quam
# sat                 satis
# est                 sum
# ne                  ne                      ne
# titulos             titulus                 titulus
# depravetApollinee   depravetApollineeo
# urbis               urbs                    urbs
# ambiguum            ambiguus                ambiguus
# rimis               rima                    rima
# herbidis            herbidus                herbidus
# que                 que
# sentibus            sentis                  sentis
# ego                 ego                     ego
# autem               autem
# tui                 tuus                    tu
# solius              solus
# utrarumque                                  uterque
# linguarum           lingua                  lingua
# peritissimo         peritus                 peritissimus
# examinivolumen      examinivolumen
# hoc                 hic                     hic
# subpono             subponus                subpono
# ut                  ut
# in                  in                      in
# eo                  is
# que                 que
# arescunt            aresco                  aresco
# ac                  ac
# caligant            caligo                  caligo
# per                 per
# te                  tu                      tu
# illustrata          illustro                illustro
# orbi                orbis                   orbis
# demum               demum                   demos
# succincta           succingo                succingo
# professione         professio               professio
# vulgentur                                   uulgo
# .                   .                       .

# %%
print(f'Token: {tokens[8].text}')
print(f'Lemma: {tokens[8].lemma_}')
print(f'Predicted lemma: {tokens[8]._.predicted_lemma}')
# Out:
# Token: fratrem
# Lemma: frater
# Predicted lemma: frater

# %%
from spacy.lookups import Lookups, load_lookups

blank_nlp = spacy.blank("la")
lookups = Lookups()

#lookups_data = load_lookups(lang=blank_nlp.vocab.lang, tables=["lemma_lookup"])
#LOOKUPS = lookups_data.get_table("lemma_lookup")

#print(LOOKUPS['Iovis'])

# %% [markdown]
# Unclassical latin

# %%
doc = nlp(text)

# %%
doc = nlp(text)

data = []

for token in doc:
    data.append([token.text, token.lemma_])

print("Before...", end="\n\n")
print(tabulate.tabulate(data, headers=['Text', 'Lemma']))
# Out:
# Before...
#
# Text                Lemma
# ------------------  ------------------
# Ad                  ad
# Hugonem             Hugon
# Eterianum           Eterianus
# doctorem            doctor
# suum                suus
# et                  et
# utraque             uterque
# origine             origo
# fratrem             frater
# Leo                 Leo
# Tuscus              tuscus
# imperatoriarum      imperatorius
# epistolarum         epistola
# interpres           interpres
# de                  de
# somniis             somnium
# et                  et
# oraculis            oraculum
# .                   .
# Quamquam            quamquam
# optime              optimus
# preceptor           preceptor
# invictum            inuictus
# imperatorem         imperator
# Manuel              Manuel
# per                 per
# fines               finis
# sequar              sequor
# Bitinie             Bitinie
# Licaonie            Licaonie
# que                 que
# fugantem            fugo
# Persas              Persa
# flexipedum          flexipedus
# hederarum           hedera
# complectentes       complector
# vestigia            uestigium
# tamen               tamen
# memorandi           memoro
# non                 non
# sum                 sum
# oblitus             obliuiscor
# somnii              somnium
# a                   ab
# te                  tu
# visi                uiso
# qui                 qui
# dictum              dictum
# inexpugnabilem      inexpugnabilis
# virum               uir
# eneo                eneo
# in                  in
# equo                equus
# supra               supra
# columnam            columna
# quam                qui
# Traces              Traces
# dicunt              dico
# augustiana          augustianus
# Bisantii            Bisantii
# sito                sino
# nobiliter           nobilito
# sedere              sedeo
# conspicabaris       conspicor
# Eodem               idem
# autem               autem
# in                  in
# loco                locus
# doctissimis         doctissimus
# quibusdam           quidam
# astantibus          asto
# latinis             latinus
# romana              romanus
# oratione            oratio
# cum                 cum
# in                  in
# quodam              quidam
# legeret             lego
# libello             libellus
# interpellanti       interpello
# tibi                tu
# soli                solum
# favorem             fauor
# prestitisse         prestito
# visus               uisus
# est                 sum
# latuit              lateo
# tunc                tunc
# utrumque            uterque
# nostrum             noster
# ea                  is
# quid                quis
# portenderet         portendo
# visio               uisio
# at                  at
# vero                uero
# eiusmodi            eiusmodi
# oraculum            oraculum
# editus              edo
# per                 per
# te                  tu
# de                  de
# filii               filius
# hominis             homo
# minoritate          minoritas
# ad                  ad
# Patrem              pater
# Deum                Deus
# libellus            libellus
# tempore             tempus
# post                post
# revelavit           reuelo
# sub                 sub
# tegumentis          tegumentum
# profecto            prŏfectus
# eneus               eneus
# ille                ille
# sonipes             sonipes
# anima               anima
# carens              careo
# altissime           alte
# sonantissime        sonantus
# que                 que
# questionis          quaestio
# erat                sum
# que                 que
# inter               inter
# Grecos              Graecus
# versabatur          uersor
# ventilatio          uentilatio
# verbum              uerbum
# scilicet            scilicet
# Dei                 Deus
# secundum            secundum
# quod                quod
# incarnatum          incarno
# patri               pater
# equale              equalis
# protestans          protestor
# rationis            ratio
# veritatis           ueritas
# que                 que
# radicitus           radicitus
# expers              expers
# ut                  ut
# quadrupes           quadrupes
# nominatus           nomino
# solvit              soluo
# autem               autem
# illam               ille
# controversiam       controuersia
# clamitante          clamito
# dicto               dictum
# libello             libellus
# augustalis          augustalis
# clementie           clementia
# decretum            decerno
# pauco               paucus
# scandali            scandalum
# fomento             fomentum
# contra              contra
# voluntatem          uoluntas
# illius              ille
# relicto             relinquo
# .                   .
# Ex                  ex
# eo                  is
# igitur              igitur
# tempore             tempus
# pectus              pectus
# sollicitudine       sollicitudo
# percussi            percutio
# sub                 sub
# corde               cor
# ignitos             ignio
# versavi             uerso
# carbones            carbo
# cogitando           cogitandus
# uti                 ut
# lene                lenis
# esset               sum
# annon               annon
# si                  si
# onirocriti          onirocro
# Grecorum            Greci
# philosophis         philosophus
# ariolanti           ariolor
# loqui               loquor
# latine              latine
# persuaderem         persuadeo
# enucleatim          enucleatim
# atque               atque
# inoffensam          inoffensus
# perspicuitatem      perspicuitas
# figmenti            figmentum
# somnialis           somnialis
# tuo                 tuus
# favore              fauor
# nostrorum           noster
# Tuscorum            Tuscus
# desiderio           desiderium
# breviter            breuiter
# reserarem           resero
# quos                qui
# quidem              quidem
# fluctu              fluctus
# percupio            percupius
# aspergi             aspergo
# undiosiore          undiosior
# ut                  ut
# irrigentur          irrigo
# affatim             affatim
# efficiantur         efficio
# que                 que
# fecundiores         fecundus
# nam                 nam
# Seres               Seres
# ut                  ut
# fertur              fero
# arbores             arbor
# suas                suus
# undis               unda
# aspergunt           aspergo
# quando              quando
# uberiorem           uberior
# lanuginem           lanugi
# que                 que
# sericum             sericum
# admittere           admitto
# nituntur            nitor
# ceterum             ceterum
# haut                haud
# facile              facilis
# est                 sum
# in                  in
# huiusmodi           huiusmodi
# versari             uersor
# pelago              pelagus
# cuius               qui
# latitudo            latitudo
# ad                  ad
# aures               auris
# usque               usque
# dehiscit            dehisco
# non                 non
# sponte              spons
# remigem             remex
# asciscens           ascisco
# invalidum           invalidus
# non                 non
# solum               solum
# enim                enim
# subtilibus          subtilis
# expositum           expono
# investigationibus   inuestigatio
# et                  et
# illos               ille
# repellunt           repello
# qui                 qui
# debilitate          debilito
# pedum               pes
# serpunt             serpo
# ut                  ut
# antipodes           antipodes
# et                  et
# eos                 is
# qui                 qui
# non                 non
# movent              moueo
# linguas             lingua
# ut                  ut
# pleraque            plerusque
# aquatilium          aquatilium
# sed                 sed
# nequemonoxilo       nequemonoxilum
# se                  sui
# navigari            nauigo
# limine              limen
# patitur             patior
# quamobrem           quamobrem
# loquelam            loquela
# imperatoriorum      imperatorius
# interpretationibus  interpretatio
# apicum              apex
# obsequentem         obsequor
# per                 per
# excubias            excubia
# interdum            interdum
# huic                hic
# translationi        translatio
# non                 non
# irrita              irritus
# spe                 spes
# addixi              addico
# totum               totus
# opus                opus
# sapientie           sapientia
# tue                 tuus
# dicaturus           dico
# iudicio             iudicium
# mei                 meus
# quidem              quidem
# auctoris            auctor
# tui                 tu
# vero                uero
# probatoris          probator
# equilibre           equilibre
# pensans             penso
# incertum            incertus
# nam                 nam
# tuum                tuus
# examen              examen
# discernere          discerno
# non                 non
# sum                 sum
# ambiguus            ambiguus
# quicquid            quisquis
# arida               aridus
# exsanguis           exsanguis
# que                 que
# poscit              posco
# ratiocinatio        ratiocinatio
# sed                 sed
# enim                enim
# desiderantissimus   desiderantisso
# nepos               nepos
# Fabricius           Fabricius
# grecarum            grecarus
# sciolus             sciolus
# et                  et
# ipse                ipse
# litterarum          littera
# somnialium          somnialis
# figmentorum         figmentum
# odoratus            odoratus
# rosaria             rosaria
# scribendi           scribo
# assiduitate         assiduitas
# me                  ego
# a                   ab
# confluentibus       confluens
# elevat              eleuo
# prestat             presto
# que                 que
# non                 non
# mediocre            mediocris
# adiumentum          adiumentum
# atque               atque
# idcirco             idcirco
# neque               neque
# nomen               nomen
# sine                sine
# subjecto            subiectus
# neque               neque
# sine                sine
# viribus             uis
# erit                sum
# editio              editio
# Sidoneis            sidoneus
# Tirenis             Tirenus
# que                 que
# sagittis            sagitta
# parum               parum
# penetrabilis        penetrabilis
# apparitura          appareo
# ut                  ut
# arbitror            arbitror
# ergo                ergo
# quisquis            quisquis
# nodosorum           nodosus
# somniorum           somnium
# fatigatur           fatigo
# involucris          inuolucrum
# si                  si
# per                 per
# aliquod             aliqui
# hic                 hic
# scriptorum          scriptor
# absolvi             absoluo
# postulet            postulo
# caveat              caueo
# pretemptare         pretempto
# plus                plus
# nosse               nosco
# quam                quam
# sat                 satis
# est                 sum
# ne                  ne
# titulos             titulus
# depravetApollinee   depravetApollineeo
# urbis               urbs
# ambiguum            ambiguus
# rimis               rima
# herbidis            herbidus
# que                 que
# sentibus            sentis
# ego                 ego
# autem               autem
# tui                 tu
# solius              solus
# utrarumque          uterque
# linguarum           lingua
# peritissimo         peritissimus
# examinivolumen      examinivolumen
# hoc                 hic
# subpono             subpono
# ut                  ut
# in                  in
# eo                  is
# que                 que
# arescunt            aresco
# ac                  ac
# caligant            caligo
# per                 per
# te                  tu
# illustrata          illustro
# orbi                orbis
# demum               demos
# succincta           succingo
# professione         professio
# vulgentur           uulgo
# .                   .

# %% [markdown]
# custom lemma with a dict

# %% [markdown]
# !!! dans le dictionnaire python : clé-valeur s'écrit {"Lemme":["token"]}

# %%
from spacy import Language

custom_lemma_lookups = {
    "digressiuncula": ["Digressiunculam"],
    "Romanus": ["Roman"],
    "Actus": ["Actor"],
}

custom_lookups = {}
for key, values in custom_lemma_lookups.items():
    for value in values:
        if value not in lookups:
            custom_lookups[value] = key

@Language.component(name="custom_lookup_lemmatizer")
def make_lookup_lemmatizer_function(doc):
    for token in doc:
        token.lemma_ = custom_lookups.get(token.text, token.lemma_)
    return doc

try:
    nlp.add_pipe("custom_lookup_lemmatizer", name="custom_lookup_lemmatizer")
except:
    # If the pipeline component is already added, we can't add it again
    pass

doc = nlp(text)

data = []

for token in doc:
    data.append([token.text, token.lemma_])

print("After...", end="\n\n")
print(tabulate.tabulate(data, headers=['Text', 'Lemma']))
# Out:
# After...
#
# Text             Lemma
# ---------------  ---------------
# 7                7
# In               in
# quod             qui
# ego              ego
# constitutus      constituo
# sum              sum
# etc              etcetera
# .                .
# Digressiunculam  digressiunculus
# continuat        continuo
# etiam            etiam
# sui              suus
# muneris          munus
# annexa           annecto
# mentione         mentio
# .                .
# Sumatur          sumo
# hinc             hinc
# octaua           octauus
# ratio            ratio
# ,                ,
# Cur              cur
# pro              pro
# impiis           impius
# Ethnicis         ethnicus
# sit              sum
# orandum          oro
# .                .
# Ratio            ratio
# est              sum
# ,                ,
# quia             quia
# Deus             Deus
# illi             ille
# singularem       singularis
# Apostolum        apostolus
# constituit       constituo
# ,                ,
# per              per
# quem             qui
# conuerterentur   conuerto
# :                :
# ergo             ergo
# digni            dignus
# sunt             sum
# pro              pro
# quibus           qui
# oretur           oro
# .                .
# Item             item
# dignos           dignus
# iudicat          iudico
# Apostolatu       apostolatus
# peculiari        peculiaris
# :                :
# et               et
# Apostolus        apostolus
# Paulus           Paulus
# dignos           dignus
# iudicat          iudico
# pro              pro
# quibus           qui
# tot              tot
# obeat            obeo
# labores          labor
# :                :
# ergo             ergo
# nos              nos
# dignos           dignus
# iudicemus        iudico
# nostris          noster
# precibus         prex
# .                .
